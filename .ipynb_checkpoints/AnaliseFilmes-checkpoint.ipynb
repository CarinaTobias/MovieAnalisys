# %% [markdown]
# ## Importacao de bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## Carga e analise inicial

# %%
# Dataset de filmes do IMDb
# O objetivo deste projeto é identificar a proporcao de pessoas entre 18 e 30 anos que assistem filmes dos anos 80

# %%
df1 = pd.read_csv("C:/Users/Carina/OneDrive/Notebook Dell/Tech/Python/movie/IMDb Ratings.csv")
df1.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
# ...

# %%
df2 = pd.read_csv("C:/Users/Carina/OneDrive/Notebook Dell/Tech/Python/movie/IMDbMovies.csv")
df2.head()
# Out:
# C:\Users\Carina\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# ...

# %%
# Seleciona somente as colunas necessárias para este projeto e renomeia para nomes mais intuitivos

df3 = df1[['imdb_title_id', 'total_votes', 'allgenders_18age_votes', 'males_18age_votes', 'females_18age_votes']]
# changing the name of the columns
#df3.columns = ['TITULO', 'TOTALDEVOTOS', PESSOADE18A30', 'HOMEMDE18A30', 'MULHERDE18A30']
df3.head()
# Out:
#   imdb_title_id  total_votes  allgenders_18age_votes  males_18age_votes  \
# 0     tt0000009          154                    38.0               24.0
# 1     tt0000574          589                   114.0              102.0
# 2     tt0001892          188                    25.0               21.0
# 3     tt0002101          446                    23.0               20.0
# 4     tt0002130         2237                   402.0              346.0
#
#    females_18age_votes
# 0                 14.0
# 1                 12.0
# 2                  4.0
# 3                  3.0
# 4                 52.0

# %%
df4 = df2[['imdb_title_id', 'title', 'year', 'genre']]
df4.head()
# Out:
#   imdb_title_id                        title  year                      genre
# 0     tt0000009                   Miss Jerry  1894                    Romance
# 1     tt0000574  The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2     tt0001892               Den sorte drøm  1911                      Drama
# 3     tt0002101                    Cleopatra  1912             Drama, History
# 4     tt0002130                    L'Inferno  1911  Adventure, Drama, Fantasy

# %%
df5 = pd.merge(df3, df4)
df5.head()
# Out:
#   imdb_title_id  total_votes  allgenders_18age_votes  males_18age_votes  \
# 0     tt0000009          154                    38.0               24.0
# 1     tt0000574          589                   114.0              102.0
# 2     tt0001892          188                    25.0               21.0
# 3     tt0002101          446                    23.0               20.0
# 4     tt0002130         2237                   402.0              346.0
#
#    females_18age_votes                        title  year  \
# 0                 14.0                   Miss Jerry  1894
# 1                 12.0  The Story of the Kelly Gang  1906
# 2                  4.0               Den sorte drøm  1911
# 3                  3.0                    Cleopatra  1912
# 4                 52.0                    L'Inferno  1911
#
#                        genre
# 0                    Romance
# 1    Biography, Crime, Drama
# 2                      Drama
# 3             Drama, History
# 4  Adventure, Drama, Fantasy

# %%
df5.isna().sum()
# Out:
# imdb_title_id                0
# total_votes                  0
# allgenders_18age_votes     706
# males_18age_votes         1465
# females_18age_votes       6521
# title                        0
# year                         0
# genre                        0
# dtype: int64

# %%
df5.dtypes
# Out:
# imdb_title_id              object
# total_votes                 int64
# allgenders_18age_votes    float64
# males_18age_votes         float64
# females_18age_votes       float64
# title                      object
# year                       object
# genre                      object
# dtype: object

# %%
df5_remove = df5.loc[(df5['year'] == 'TV Movie 2019')]
df5_clean = df5.drop(df5_remove.index)

# %%
df5_clean['year'] = df5_clean['year'].astype(int)
df5_clean.dtypes
# Out:
# imdb_title_id              object
# total_votes                 int64
# allgenders_18age_votes    float64
# males_18age_votes         float64
# females_18age_votes       float64
# title                      object
# year                        int32
# genre                      object
# dtype: object

# %%
total_votos1980 = 0
teenA1980 = 0
teenD1980 = 0

for i in df5_clean:
    if year < 1980:
        teenA1980 += allgenders_18age_votes

print(teenA1980)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-174-e71e4538a378> in <module>
#       4
#       5 for i in df5_clean:
# ----> 6     if year < 1980:
#       7         teenA1980 += allgenders_18age_votes
#       8
#
# NameError: name 'year' is not defined

# %%
total_votes = (df5['total_votes'].value_counts())
            
print(total_votes)
prob = teenA1980 / total_votos1980
